# %% [markdown]
# # Ungraded Lab: Data Augmentation
#
# In the previous lessons, you saw that having a high training accuracy does not automatically mean having a good predictive model. It can still perform poorly on new data because it has overfit to the training set. In this lab, you will see how to avoid that using _data augmentation_. This increases the amount of training data by modifying the existing training data's properties. For example, in image data, you can apply different preprocessing techniques such as rotate, flip, shear, or zoom on your existing images so you can simulate other data that the model should also learn from. This way, the model would see more variety in the images during training so it will infer better on new, previously unseen data.
#
# Let's see how you can do this in the following sections.

# %% [markdown]
# ## Baseline Performance
#
# You will start with a model that's very effective at learning `Cats vs Dogs` without data augmentation. It's similar to the previous models that you have used. Note that there are four convolutional layers with 32, 64, 128 and 128 convolutions respectively. The code is basically the same from the previous lab so we won't go over the details step by step since you've already seen it before.

# %%
# First import the necessary libraries
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
BASE_DIR = 'cats_and_dogs_filtered'

train_dir = os.path.join(BASE_DIR, 'train')
validation_dir = os.path.join(BASE_DIR, 'validation')

# Directory with training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

print(f"Contents of base directory: {os.listdir(BASE_DIR)}")

print(f"\nContents of train directory: {os.listdir(train_dir)}")

print(f"\nContents of validation directory: {os.listdir(validation_dir)}")
# Out:
# Contents of base directory: ['train', 'validation']
#
# Contents of train directory: ['dogs', 'cats']
#
# Contents of validation directory: ['dogs', 'cats']

# %% [markdown]
# You will place the model creation inside a function so you can easily initialize a new one when you use data augmentation later in this notebook.

# %%
def create_model():
    '''Creates a CNN with 4 convolutional layers'''
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(150, 150, 3)),
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %% [markdown]
# You will preprocess the training and validation datasets as usual.

# %%
# Instantiate the training dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Instantiate the validation dataset
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Optimize the datasets for training
SHUFFLE_BUFFER_SIZE = 1000
PREFETCH_BUFFER_SIZE = tf.data.AUTOTUNE

train_dataset_final = (train_dataset
                       .cache()
                       .shuffle(SHUFFLE_BUFFER_SIZE)
                       .prefetch(PREFETCH_BUFFER_SIZE)
                       )

validation_dataset_final = (validation_dataset
                            .cache()
                            .prefetch(PREFETCH_BUFFER_SIZE)
                            )
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# You will train only for 20 epochs to save time but feel free to increase this if you want.

# %%
# Constant for epochs
EPOCHS = 20

# Create a new model
model = create_model()

# Setup the training parameters
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

# Train the model
history = model.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727426447.259648     279 service.cc:145] XLA service 0x7fdaf0004430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727426447.259732     279 service.cc:153]   StreamExecutor device (0): NVIDIA A10G, Compute Capability 8.6
# I0000 00:00:1727426449.273706     279 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 - 6s - 56ms/step - accuracy: 0.5245 - loss: 0.6906 - val_accuracy: 0.5270 - val_loss: 0.6880
# Epoch 2/20
# 100/100 - 1s - 7ms/step - accuracy: 0.5785 - loss: 0.6702 - val_accuracy: 0.6120 - val_loss: 0.6564
# Epoch 3/20
# 100/100 - 1s - 7ms/step - accuracy: 0.6305 - loss: 0.6434 - val_accuracy: 0.6010 - val_loss: 0.6437
# Epoch 4/20
# 100/100 - 1s - 7ms/step - accuracy: 0.6750 - loss: 0.6045 - val_accuracy: 0.6660 - val_loss: 0.6200
# Epoch 5/20
# 100/100 - 1s - 7ms/step - accuracy: 0.6840 - loss: 0.5763 - val_accuracy: 0.6780 - val_loss: 0.5902
# Epoch 6/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7160 - loss: 0.5496 - val_accuracy: 0.6960 - val_loss: 0.5870
# Epoch 7/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7310 - loss: 0.5299 - val_accuracy: 0.6790 - val_loss: 0.5867
# Epoch 8/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7415 - loss: 0.5136 - val_accuracy: 0.7080 - val_loss: 0.5626
# Epoch 9/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7665 - loss: 0.4857 - val_accuracy: 0.7140 - val_loss: 0.5578
# Epoch 10/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7650 - loss: 0.4689 - val_accuracy: 0.7110 - val_loss: 0.5722
# Epoch 11/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7800 - loss: 0.4457 - val_accuracy: 0.7090 - val_loss: 0.5625
# Epoch 12/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8130 - loss: 0.4261 - val_accuracy: 0.7020 - val_loss: 0.5774
# Epoch 13/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8145 - loss: 0.4028 - val_accuracy: 0.7300 - val_loss: 0.5479
# Epoch 14/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8290 - loss: 0.3787 - val_accuracy: 0.7290 - val_loss: 0.5682
# Epoch 15/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8460 - loss: 0.3535 - val_accuracy: 0.7160 - val_loss: 0.5845
# Epoch 16/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8665 - loss: 0.3311 - val_accuracy: 0.7550 - val_loss: 0.5562
# Epoch 17/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8635 - loss: 0.3129 - val_accuracy: 0.7280 - val_loss: 0.5681
# Epoch 18/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8860 - loss: 0.2853 - val_accuracy: 0.7070 - val_loss: 0.6283
# Epoch 19/20
# 100/100 - 1s - 7ms/step - accuracy: 0.9060 - loss: 0.2619 - val_accuracy: 0.7160 - val_loss: 0.6264
# Epoch 20/20
# 100/100 - 1s - 7ms/step - accuracy: 0.9020 - loss: 0.2379 - val_accuracy: 0.7180 - val_loss: 0.6468

# %% [markdown]
# You will then visualize the loss and accuracy with respect to the training and validation set. You will again use a convenience function so it can be reused later. This function accepts a [History](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History) object which contains the results of the `fit()` method you ran above.

# %%
def plot_loss_acc(history):
    '''Plots the training and validation loss and accuracy from a history object'''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    fig, ax = plt.subplots(1,2, figsize=(12, 6))
    ax[0].plot(epochs, acc, 'bo', label='Training accuracy')
    ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
    ax[0].set_title('Training and validation accuracy')
    ax[0].set_xlabel('epochs')
    ax[0].set_ylabel('accuracy')
    ax[0].legend()

    ax[1].plot(epochs, loss, 'bo', label='Training Loss')
    ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
    ax[1].set_title('Training and validation loss')
    ax[1].set_xlabel('epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()

    plt.show()

# %%
# Plot training results
plot_loss_acc(history)

# %% [markdown]
# From the results above, you'll see the training accuracy is more than 90%, and the validation accuracy is in the 70%-80% range. This is a great example of _overfitting_ -- which in short means that it can do very well with images it has seen before, but not so well with images it hasn't.

# %% [markdown]
# ## Data augmentation
#
# One simple method to avoid overfitting is to augment the images. If you think about it, most pictures of a cat are very similar -- the ears are at the top, the eyes are below the ears etc. Things like the distance between the eyes and ears will always be quite similar too.
#
# What if you tweak with the images a bit -- rotate the image, squash it, etc.  That's what image augementation is all about.
#
# To do that, you will build a data augmentation model with [preprocessing layers for image augmentation](https://www.tensorflow.org/guide/keras/preprocessing_layers#image_data_augmentation). This will transform the data during training to introduce variations of the same image. Let's quickly go over the layers you will use in this exercise.
#
# * [RandomFlip](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomFlip) is for randomly flipping the images horizontally, vertically, or both.
# * [RandomRotation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomRotation) rotates the image by an angle within a given range.
# * [RandomTranslation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomTranslation) shifts pictures vertically and horizontally.
# * [RandomZoom](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomZoom) zooms into or out of the images.
#
# In addition, some of these layers have a `fill_mode` parameter. This is the strategy used for filling newly created pixels, which can appear after a rotation or a width/height shift.
#
# The code below will create this model with some set parameters. After you complete this lab, feel free to modify these and see the impact on the results.

# %%
# Define fill mode.
FILL_MODE = 'nearest'

# Create the augmentation model.
data_augmentation = tf.keras.Sequential([
    # Specify the input shape.
    tf.keras.Input(shape=(150,150,3)),
    # Add the augmentation layers
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomTranslation(0.2,0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomZoom(0.2, fill_mode=FILL_MODE)
    ])

# %% [markdown]
# You will define a utility function that lets you preview how the transformed images look like. It will take in a sample image, then output a given number of augmented images using the model you defined above.

# %%
def demo_augmentation(sample_image, model, num_aug):
    '''Takes a single image array, then uses a model to generate num_aug transformations'''

    # Instantiate preview list
    image_preview = []

    # Convert input image to a PIL image instance
    sample_image_pil = tf.keras.utils.array_to_img(sample_image)

    # Append the result to the list
    image_preview.append(sample_image_pil)

    # Apply the image augmentation and append the results to the list
    for i in range(NUM_AUG):
        sample_image_aug = model(tf.expand_dims(sample_image, axis=0))
        sample_image_aug_pil = tf.keras.utils.array_to_img(tf.squeeze(sample_image_aug))
        image_preview.append(sample_image_aug_pil)

    # Instantiate a subplot
    fig, axes = plt.subplots(1, NUM_AUG + 1, figsize=(12, 12))

    # Preview the images.
    for index, ax in enumerate(axes):
        ax.imshow(image_preview[index])
        ax.set_axis_off()

        if index == 0:
            ax.set_title('original')
        else:
            ax.set_title(f'augment {index}')

# %% [markdown]
# Now get some images from the dataset.

# %%
# Get a batch of images
sample_batch = list(train_dataset.take(1))[0][0]
print(f'images per batch: {len(sample_batch)}')
# Out:
# images per batch: 20

# %% [markdown]
# This will show sample transformations for the first 4 images of the sample batch. Notice that each call of the `data_augmentation` model yields a different output. It's like adding more images to your dataset without you having to collect them manually.

# %%
NUM_AUG = 4

# Apply the transformations to the first 4 images
demo_augmentation(sample_batch[0], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[1], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[2], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[3], data_augmentation, NUM_AUG)

# Uncomment the line below to delete the variable to free up some memory
# del sample_batch

# %% [markdown]
# Now that you see what the preprocessing layers do, you can prepend these to the base model so it can generate transformed images to the base model. Do note that these layers are only active while training. They are automatically disabled during prediction and evaluation.

# %%
# Instantiate the base model
model_without_aug = create_model()

# Prepend the data augmentation layers to the base model
model_with_aug = tf.keras.models.Sequential([
    data_augmentation,
    model_without_aug
])

# Compile the model
model_with_aug.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
    metrics=['accuracy'])

# %% [markdown]
# Because you now have virtually more data, it will also take the model more time to learn the relevant features. Without data augmentation, your model already started overfitting to the training set within 20 epochs. Try training this model for 80 epochs and observe the results.

# %%
EPOCHS=80

# Train the new model
history_with_aug = model_with_aug.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/80
# 100/100 - 4s - 37ms/step - accuracy: 0.5165 - loss: 0.6940 - val_accuracy: 0.5020 - val_loss: 0.6896
# Epoch 2/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5405 - loss: 0.6900 - val_accuracy: 0.6090 - val_loss: 0.6821
# Epoch 3/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5415 - loss: 0.6887 - val_accuracy: 0.5800 - val_loss: 0.6725
# Epoch 4/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5570 - loss: 0.6818 - val_accuracy: 0.6020 - val_loss: 0.6617
# Epoch 5/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5670 - loss: 0.6742 - val_accuracy: 0.6150 - val_loss: 0.6498
# Epoch 6/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5900 - loss: 0.6641 - val_accuracy: 0.6150 - val_loss: 0.6406
# Epoch 7/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6110 - loss: 0.6542 - val_accuracy: 0.5330 - val_loss: 0.7065
# Epoch 8/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6340 - loss: 0.6470 - val_accuracy: 0.6490 - val_loss: 0.6204
# Epoch 9/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6220 - loss: 0.6434 - val_accuracy: 0.5990 - val_loss: 0.6586
# Epoch 10/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6415 - loss: 0.6342 - val_accuracy: 0.6580 - val_loss: 0.6064
# Epoch 11/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6340 - loss: 0.6297 - val_accuracy: 0.6770 - val_loss: 0.5908
# Epoch 12/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6470 - loss: 0.6225 - val_accuracy: 0.6870 - val_loss: 0.5801
# Epoch 13/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6615 - loss: 0.6100 - val_accuracy: 0.5710 - val_loss: 0.7558
# Epoch 14/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6720 - loss: 0.6042 - val_accuracy: 0.6860 - val_loss: 0.5712
# Epoch 15/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6690 - loss: 0.6019 - val_accuracy: 0.6520 - val_loss: 0.6263
# Epoch 16/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6750 - loss: 0.5981 - val_accuracy: 0.6000 - val_loss: 0.6688
# Epoch 17/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6805 - loss: 0.5975 - val_accuracy: 0.7040 - val_loss: 0.5531
# Epoch 18/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6850 - loss: 0.5799 - val_accuracy: 0.6960 - val_loss: 0.5723
# Epoch 19/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6855 - loss: 0.5953 - val_accuracy: 0.7010 - val_loss: 0.5528
# Epoch 20/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6895 - loss: 0.5831 - val_accuracy: 0.7040 - val_loss: 0.5531
# Epoch 21/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6900 - loss: 0.5801 - val_accuracy: 0.7200 - val_loss: 0.5457
# Epoch 22/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6800 - loss: 0.5829 - val_accuracy: 0.6960 - val_loss: 0.5679
# Epoch 23/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6945 - loss: 0.5792 - val_accuracy: 0.7200 - val_loss: 0.5423
# Epoch 24/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6920 - loss: 0.5685 - val_accuracy: 0.7240 - val_loss: 0.5344
# Epoch 25/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7070 - loss: 0.5762 - val_accuracy: 0.7180 - val_loss: 0.5330
# Epoch 26/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7095 - loss: 0.5632 - val_accuracy: 0.7410 - val_loss: 0.5243
# Epoch 27/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7110 - loss: 0.5561 - val_accuracy: 0.7160 - val_loss: 0.5479
# Epoch 28/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7125 - loss: 0.5566 - val_accuracy: 0.6950 - val_loss: 0.5771
# Epoch 29/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7225 - loss: 0.5590 - val_accuracy: 0.7350 - val_loss: 0.5134
# Epoch 30/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7145 - loss: 0.5530 - val_accuracy: 0.7380 - val_loss: 0.5141
# Epoch 31/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7330 - loss: 0.5427 - val_accuracy: 0.7270 - val_loss: 0.5144
# Epoch 32/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7145 - loss: 0.5537 - val_accuracy: 0.7260 - val_loss: 0.5219
# Epoch 33/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7250 - loss: 0.5413 - val_accuracy: 0.7480 - val_loss: 0.5023
# Epoch 34/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7215 - loss: 0.5380 - val_accuracy: 0.7290 - val_loss: 0.5152
# Epoch 35/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7190 - loss: 0.5467 - val_accuracy: 0.7420 - val_loss: 0.5022
# Epoch 36/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7320 - loss: 0.5362 - val_accuracy: 0.7460 - val_loss: 0.5027
# Epoch 37/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7240 - loss: 0.5474 - val_accuracy: 0.7390 - val_loss: 0.5078
# Epoch 38/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7405 - loss: 0.5317 - val_accuracy: 0.7170 - val_loss: 0.5467
# Epoch 39/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7245 - loss: 0.5389 - val_accuracy: 0.7400 - val_loss: 0.5021
# Epoch 40/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7355 - loss: 0.5325 - val_accuracy: 0.7490 - val_loss: 0.4957
# Epoch 41/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7380 - loss: 0.5224 - val_accuracy: 0.7540 - val_loss: 0.4927
# Epoch 42/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7360 - loss: 0.5299 - val_accuracy: 0.7430 - val_loss: 0.5001
# Epoch 43/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7325 - loss: 0.5282 - val_accuracy: 0.7430 - val_loss: 0.5134
# Epoch 44/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7375 - loss: 0.5158 - val_accuracy: 0.7450 - val_loss: 0.5127
# Epoch 45/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7300 - loss: 0.5250 - val_accuracy: 0.7590 - val_loss: 0.4835
# Epoch 46/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7305 - loss: 0.5220 - val_accuracy: 0.7380 - val_loss: 0.4960
# Epoch 47/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7365 - loss: 0.5273 - val_accuracy: 0.7340 - val_loss: 0.5204
# Epoch 48/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7450 - loss: 0.5066 - val_accuracy: 0.7660 - val_loss: 0.4726
# Epoch 49/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7555 - loss: 0.5062 - val_accuracy: 0.7600 - val_loss: 0.4881
# Epoch 50/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7340 - loss: 0.5182 - val_accuracy: 0.7500 - val_loss: 0.4947
# Epoch 51/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7460 - loss: 0.5159 - val_accuracy: 0.7420 - val_loss: 0.5044
# Epoch 52/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7430 - loss: 0.5133 - val_accuracy: 0.7500 - val_loss: 0.4963
# Epoch 53/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7540 - loss: 0.5047 - val_accuracy: 0.7680 - val_loss: 0.4774
# Epoch 54/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7470 - loss: 0.5101 - val_accuracy: 0.7620 - val_loss: 0.4828
# Epoch 55/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7615 - loss: 0.4930 - val_accuracy: 0.7590 - val_loss: 0.4772
# Epoch 56/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7465 - loss: 0.5000 - val_accuracy: 0.7570 - val_loss: 0.4896
# Epoch 57/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7630 - loss: 0.5014 - val_accuracy: 0.7500 - val_loss: 0.4935
# Epoch 58/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7595 - loss: 0.5029 - val_accuracy: 0.7530 - val_loss: 0.5043
# Epoch 59/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7605 - loss: 0.5010 - val_accuracy: 0.7650 - val_loss: 0.4771
# Epoch 60/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7585 - loss: 0.4924 - val_accuracy: 0.7660 - val_loss: 0.4708
# Epoch 61/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7645 - loss: 0.4840 - val_accuracy: 0.7440 - val_loss: 0.5225
# Epoch 62/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7485 - loss: 0.4937 - val_accuracy: 0.7510 - val_loss: 0.4822
# Epoch 63/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7635 - loss: 0.4894 - val_accuracy: 0.7700 - val_loss: 0.4700
# Epoch 64/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7640 - loss: 0.4905 - val_accuracy: 0.7570 - val_loss: 0.4795
# Epoch 65/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7565 - loss: 0.4917 - val_accuracy: 0.7440 - val_loss: 0.5038
# Epoch 66/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7680 - loss: 0.4826 - val_accuracy: 0.7640 - val_loss: 0.4755
# Epoch 67/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7605 - loss: 0.4940 - val_accuracy: 0.7800 - val_loss: 0.4725
# Epoch 68/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7570 - loss: 0.4839 - val_accuracy: 0.7440 - val_loss: 0.4994
# Epoch 69/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7730 - loss: 0.4808 - val_accuracy: 0.7680 - val_loss: 0.4704
# Epoch 70/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7530 - loss: 0.4909 - val_accuracy: 0.7520 - val_loss: 0.5057
# Epoch 71/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7695 - loss: 0.4739 - val_accuracy: 0.7590 - val_loss: 0.4747
# Epoch 72/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7680 - loss: 0.4832 - val_accuracy: 0.7440 - val_loss: 0.4974
# Epoch 73/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7810 - loss: 0.4819 - val_accuracy: 0.7840 - val_loss: 0.4505
# Epoch 74/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7790 - loss: 0.4675 - val_accuracy: 0.7760 - val_loss: 0.4518
# Epoch 75/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7760 - loss: 0.4713 - val_accuracy: 0.7790 - val_loss: 0.4511
# Epoch 76/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7655 - loss: 0.4825 - val_accuracy: 0.7370 - val_loss: 0.5324
# Epoch 77/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7570 - loss: 0.4884 - val_accuracy: 0.7340 - val_loss: 0.5286
# Epoch 78/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7735 - loss: 0.4714 - val_accuracy: 0.7570 - val_loss: 0.4858
# Epoch 79/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7820 - loss: 0.4575 - val_accuracy: 0.7740 - val_loss: 0.4556
# Epoch 80/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7830 - loss: 0.4649 - val_accuracy: 0.7770 - val_loss: 0.4564

# %%
# Plot the results of training with data augmentation
plot_loss_acc(history_with_aug)

# %% [markdown]
# As you can see, the training accuracy has gone down compared to the baseline. This is expected because (as a result of data augmentation) there are more variety in the images so the model will need more runs to learn from them. The good thing is the validation accuracy is no longer stalling and is more in line with the training results. This means that the model is now performing better on unseen data.

# %% [markdown]
# ## Wrap Up
#
# This exercise showed a simple trick to avoid overfitting. You can improve your baseline results by simply tweaking the same images you have already. The image augmentation preprocessing layers will do just that. Try to modify the values in the augmentation model and see what results you get. You can also add other preprocessing layers for random contrast, brightness, or cropping.
#
# Take note that this will not work for all cases. In the next lesson, Laurence will show a scenario where data augmentation will not help improve your validation accuracy.
#
# Before going back to the classroom, run the cell below to free up resources for the next lab. You might see a pop-up about restarting the kernel afterwards. You can safely ignore it and just press Ok. You can then close this lab, then go back to the classroom for the next lecture. See you there!

# %%
# Shutdown the kernel to free up resources. 
# Note: You can expect a pop-up when you run this cell. You can safely ignore that and just press `Ok`.

from IPython import get_ipython

k = get_ipython().kernel

k.do_shutdown(restart=False)
# Out:
# {'status': 'ok', 'restart': False}
